# %%
import os
from dotenv import load_dotenv

# 📍 Chemin absolu vers ton fichier .env
env_path = r"C:\Users\hp\Documents\Albert School\M1\Gen AI\smartmeal\.env"

# Charger le .env manuellement
loaded = load_dotenv(dotenv_path=env_path)
print("✅ .env chargé :", loaded)
print("🔑 OPENAI_API_KEY =", os.getenv("OPENAI_API_KEY"))
# Out:
# ✅ .env chargé : True
# 🔑 OPENAI_API_KEY = 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

# %%
from openai import OpenAI
import os

client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))

response = client.chat.completions.create(
    model="gpt-4o-mini",
    messages=[{"role": "user", "content": "Donne-moi une idée de dîner équilibré pour ce soir"}],
)

print(response.choices[0].message.content)
# Out:
# Voici une idée de dîner équilibré :
#
# **Plat principal :** Filet de saumon grillé avec des herbes (comme du thym et du citron)
# **Accompagnement :** Quinoa ou riz complet
# **Légumes :** Mélange de légumes rôtis (comme des courgettes, des poivrons et des carottes) avec un filet d'huile d'olive et des épices
# **Salade :** Une petite salade verte avec des épinards frais, des tomates cerises, des concombres et une vinaigrette légère
# **Dessert :** Un yaourt nature avec des fruits frais (comme des baies ou une tranche de pomme) et une cuillère de miel
#
# Ce menu est riche en protéines, en fibres, en vitamines et en minéraux, tout en étant savoureux et satisfaisant. Bon appétit !
